# %%
import pandas as pd

# %%
df=pd.DataFrame({
    "order date":[
        "2024-03-01",
        "2024-01-28",
        "2024-03-14",
        "2024-02-01",
        "2024-03-10",
        "2024-02-01",
        "2024-05-05",
        "2024-01-15",
        "2024-10-15",
        "2024-01-03"
        
    ],
    "Product Name": [
        "Laptop",
        "Mouse",
        "Printer",
        "Tablet",
        "Laptop",
        "Moniter",
        "Mouse",
        "Printer",
        "Smartwatch",
        "Mouse"
        
    ],
    "Category": [
        "Electronics",
        "Accessories",
        "Office",
        "Electronics",
        "Accessories",
        "Electronics",
        "Accessories",
        "Office",
        "Electronics",
        "Accessories",
    ],
    "Region": [
        "North",
        "South",
        "East",
        "west",
        "North",
        "South",
        "East",
        "west",
        "North",
        "South",
    ],
    "Quantity": [
        2,
        5,
        3,
        4,
        1,
        2,
        6,
        2,
        3,
        5
    ],
    "Sales": [
        50000,
        2500,
        9000,
        30000,
        55000,
        16000,
        3000,
        6000,
        45000,
        2500
    ],
    "Profit": [
        10000,
        500,
        1500,
        6000,
        11000,
        3000,
        None,
        1000,
        9000,
        500
    ]
})
print("1. ORIGINAL DATASET")
display(df)
# Out:
# 1. ORIGINAL DATASET
#    order date Product Name     Category Region  Quantity  Sales   Profit
# 0  2024-03-01       Laptop  Electronics  North         2  50000  10000.0
# 1  2024-01-28        Mouse  Accessories  South         5   2500    500.0
# 2  2024-03-14      Printer       Office   East         3   9000   1500.0
# 3  2024-02-01       Tablet  Electronics   west         4  30000   6000.0
# 4  2024-03-10       Laptop  Accessories  North         1  55000  11000.0
# 5  2024-02-01      Moniter  Electronics  South         2  16000   3000.0
# 6  2024-05-05        Mouse  Accessories   East         6   3000      NaN
# 7  2024-01-15      Printer       Office   west         2   6000   1000.0
# 8  2024-10-15   Smartwatch  Electronics  North         3  45000   9000.0
# 9  2024-01-03        Mouse  Accessories  South         5   2500    500.0

# %%
print("2. FIRST 5 RECORDS")
print(df.head())
# Out:
# 2. FIRST 5 RECORDS
#    order date Product Name     Category Region  Quantity  Sales   Profit
# 0  2024-03-01       Laptop  Electronics  North         2  50000  10000.0
# 1  2024-01-28        Mouse  Accessories  South         5   2500    500.0
# 2  2024-03-14      Printer       Office   East         3   9000   1500.0
# 3  2024-02-01       Tablet  Electronics   west         4  30000   6000.0
# 4  2024-03-10       Laptop  Accessories  North         1  55000  11000.0

# %%
print("LAST 5 RECORDS")
print(df.tail())
# Out:
# LAST 5 RECORDS
#    order date Product Name     Category Region  Quantity  Sales  Profit
# 5  2024-02-01      Moniter  Electronics  South         2  16000  3000.0
# 6  2024-05-05        Mouse  Accessories   East         6   3000     NaN
# 7  2024-01-15      Printer       Office   west         2   6000  1000.0
# 8  2024-10-15   Smartwatch  Electronics  North         3  45000  9000.0
# 9  2024-01-03        Mouse  Accessories  South         5   2500   500.0

# %%
print("3.DATA SHAPE")
print(df.shape)
# Out:
# 3.DATA SHAPE
# (10, 7)

# %%
print(df.columns)
# Out:
# Index(['order date', 'Product Name', 'Category', 'Region', 'Quantity', 'Sales',
#        'Profit'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# order date       object
# Product Name     object
# Category         object
# Region           object
# Quantity          int64
# Sales             int64
# Profit          float64
# dtype: object

# %%
print("4.Descriptive")
print(df.describe())
# Out:
# 4.Descriptive
#         Quantity         Sales        Profit
# count  10.000000     10.000000      9.000000
# mean    3.300000  21900.000000   4722.222222
# std     1.636392  21209.012759   4330.928820
# min     1.000000   2500.000000    500.000000
# 25%     2.000000   3750.000000   1000.000000
# 50%     3.000000  12500.000000   3000.000000
# 75%     4.750000  41250.000000   9000.000000
# max     6.000000  55000.000000  11000.000000

# %%
print(df.isnull().sum())
# Out:
# order date      0
# Product Name    0
# Category        0
# Region          0
# Quantity        0
# Sales           0
# Profit          1
# dtype: int64

# %%
print(df[df.isnull().any(axis=1)])
# Out:
#    order date Product Name     Category Region  Quantity  Sales  Profit
# 6  2024-05-05        Mouse  Accessories   East         6   3000     NaN

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
display(df[df.duplicated()])
# Out:
# Empty DataFrame
# Columns: [order date, Product Name, Category, Region, Quantity, Sales, Profit]
# Index: []
